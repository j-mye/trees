# %% [markdown]
# ### Words

# %% [markdown]
# ### Making dataframe

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
import sys
sys.path.append('..')
from scripts.load_data import load_data

df = load_data()
df.head()
# Out:
#    Site ID Quarter Section Address     Street   Side Site   On Street  \
# 0   166587             537    3407  1ST PL /S   Side    1  HOLT AV /W
# 1   166592             537    3407  1ST PL /S   Side    2  HOLT AV /W
# 2   166828             537    3410  1ST PL /S  Front    1   1ST PL /S
# 3   166831             537    3413  1ST PL /S  Front    1   1ST PL /S
# 4   166834             537    3419  1ST PL /S  Front    1   1ST PL /S
#
#                                              Species   DBH   Latitude  ...  \
# 0             MAPLE, NORWAY (NOR) (ACER PLATANOIDES)  12.0  42.982287  ...
# 1  PEAR, CALLERY CHANTICLEER (CCP) (PYRUS CALLERY...   4.0  42.982285  ...
# 2             MAPLE, NORWAY (NOR) (ACER PLATANOIDES)  12.0  42.982162  ...
# 3             MAPLE, NORWAY (NOR) (ACER PLATANOIDES)  17.0  42.982124  ...
# 4  HONEYLOCUST, THORNLESS SKYLINE (SKL) (GLEDITSI...   3.0  42.982006  ...
#
#    Side of Street      Site Type Valuation Total Site Last Changed On  \
# ...

# %%
import sys
sys.path.append('..')
from scripts.data_filler import fill_missing_data

df_filled = fill_missing_data(df)

# Made ONLY for visual purposes seen below
df_original = df.copy()
df_original['Height'] = df_original['Height'].fillna(0)
df_original['Crown Width'] = df_original['Crown Width'].fillna(0)

# %%
plt.figure(figsize=(12, 10))
sns.set_style('whitegrid')

fig, axes = plt.subplots(2, 2, figsize=(12, 10), sharex='col')

sns.scatterplot(data=df_original, x='DBH', y='Height', ax=axes[0, 0], color='C0')
axes[0, 0].set_title('Height vs DBH — original')
axes[0, 0].set_ylabel('Height')

sns.scatterplot(data=df_original, x='DBH', y='Crown Width', ax=axes[1, 0], color='C0')
axes[1, 0].set_title('Crown Width vs DBH — original')
axes[1, 0].set_xlabel('DBH')
axes[1, 0].set_ylabel('Crown Width')

sns.scatterplot(data=df_filled, x='DBH', y='Height', ax=axes[0, 1], color='C1')
axes[0, 1].set_title('Height vs DBH — filled')

sns.scatterplot(data=df_filled, x='DBH', y='Crown Width', ax=axes[1, 1], color='C1')
axes[1, 1].set_title('Crown Width vs DBH — filled')
axes[1, 1].set_xlabel('DBH')

for ax in axes.flat:
    ax.label_outer()
    ax.legend(framealpha=0.6)

plt.suptitle('Origina vs Filled')
plt.tight_layout(rect=[0, 0, 1, 1])
plt.show()
# Out:
# C:\Users\myersjr\AppData\Local\Temp\ipykernel_23568\485064242.py:24: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(framealpha=0.6)
