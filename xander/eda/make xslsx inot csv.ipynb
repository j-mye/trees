# %%
import pandas as pd

# Load data with proper settings
service_df = pd.read_excel('../../data/10 year service requests.xls')
inventory_df = pd.read_excel('../../data/Inventory 1-15-26.xlsx')

# %%
service_df.to_csv('../../data/10 year service requests.csv', index=False)
inventory_df.to_csv('../../data/Inventory 1-15-26.csv', index=False)
